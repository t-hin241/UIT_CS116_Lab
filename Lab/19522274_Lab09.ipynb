# %% [markdown]
# **Lab09: CNN và các biến thể**
#
# * Họ và tên: Hồ Thịnh
# * MSSV: 19522274
#
# Yêu cầu: Chạy file colab với guideline như sau:
#
# * Bước 1: Train và đánh giá trên tập test kiến trúc mạng LeNet với bộ MNIST
#
# * Bước 2: Thử thay đổi cấu hình của LeNet thành các biến thể. Một số gợi ý:
#
#     - Bỏ hết activation
#
#     - Bỏ hết Convolution layer
#
#     - Bỏ hết Pooling layer
#
# * Bước 3: đánh giá độ chính xác trên các biến thể trên

# %% [markdown]
# #Install Package  & Load MNIST Dataset

# %%
import numpy as np
import tensorflow as tf
import keras
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, Flatten, Add, AveragePooling2D
from keras.models import load_model, Model
#from keras.objectives import categorical_crossentropy
from keras.datasets import mnist
from collections import Counter
from sklearn import preprocessing

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
def onehot(y):
  oh = np.zeros((y.shape[0], 10))
  for i in range(y.shape[0]):
    oh[i, int(y[i])]=1
  return oh

def norm_zero_one(x_train):
  min_val = np.min(x_train)
  max_val = np.max(x_train)
  x_train_norm = (x_train-min_val)/(max_val-min_val)
  return x_train_norm

def norm_normal_dist(x_train):
  mean_val = np.mean(x_train)
  std_val = np.std(x_train)
  x_train_norm = (x_train-mean_val)/std_val
  return x_train_norm

# %%
#normalize data
y_train_oh = onehot(y_train)
y_train_oh.shape

y_test_oh = onehot(y_test)
y_test_oh.shape

x_train_norm = x_train / 255.0
x_test_norm = x_test / 255.0

# %% [markdown]
# #Install LeNetCNN

# %%
#base
class LeNetCNN:
  # constructor
  def __init__(self):
    self.model = None

  # Define structure of the CNN
  def build(self, input_dim):
    input = Input(shape = input_dim) # X dau vao cua minh
    C1 = Conv2D(6, (3, 3), padding='same', activation='relu')(input)
    S2 = MaxPooling2D(pool_size=(2, 2), padding="same")(C1)
    C3 = Conv2D(16, (3, 3), padding='same', activation='relu')(S2)
    S4 = MaxPooling2D(pool_size=(2, 2), padding="same")(C3)

    flat = Flatten()(S4)
    # These like ANN
    F5 = Dense(120, activation='relu', use_bias=True)(flat)
    F6 = Dense(84, activation='relu', use_bias=True)(F5)
    output = Dense(10, activation='softmax', use_bias=True)(F6) # y~ output
    self.model = Model(input, output)
  
  # Train the model
  def train(self, x_train, y_train, x_val, y_val): # x_train chinh la X, y_train chinh la ground-truth
    sgd = keras.optimizers.SGD(learning_rate=0.01)
    adam = keras.optimizers.Adam(learning_rate=0.01)
    self.model.compile(optimizer=sgd, loss = 'categorical_crossentropy', metrics=['accuracy'])
    self.model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = 50, batch_size = 128)
  
  # Load model from file
  def load(self, model_file):
    self.model = load_model(model_file)
  
  # save the trained model
  def save(self, model_file):
    self.model.save(model_file)
  
  # Show the architecture of the model
  def summary(self):
    self.model.summary()

  # Test the model with a given input
  def predict(self, x_test):
    return self.model.predict(x_test)

# %%
#LeNetCNN without Activation
class LeNetCNN_v1:
  # constructor
  def __init__(self):
    self.model = None

  # Define structure of the CNN
  def build(self, input_dim):
    input = Input(shape = input_dim) # X dau vao cua minh
    C1 = Conv2D(6, (3, 3), padding='same')(input)
    S2 = MaxPooling2D(pool_size=(2, 2), padding="same")(C1)
    C3 = Conv2D(16, (3, 3), padding='same')(S2)
    S4 = MaxPooling2D(pool_size=(2, 2), padding="same")(C3)

    flat = Flatten()(S4)
    # These like ANN
    F5 = Dense(120, use_bias=True)(flat)
    F6 = Dense(84, use_bias=True)(F5)
    output = Dense(10, use_bias=True)(F6) # y~ output
    self.model = Model(input, output)
  
  # Train the model
  def train(self, x_train, y_train, x_val, y_val): # x_train chinh la X, y_train chinh la ground-truth
    sgd = keras.optimizers.SGD(learning_rate=0.01)
    adam = keras.optimizers.Adam(learning_rate=0.01)
    self.model.compile(optimizer=sgd, loss = 'categorical_crossentropy', metrics=['accuracy'])
    self.model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = 50, batch_size = 128)
  
  # Load model from file
  def load(self, model_file):
    self.model = load_model(model_file)
  
  # save the trained model
  def save(self, model_file):
    self.model.save(model_file)
  
  # Show the architecture of the model
  def summary(self):
    self.model.summary()

  # Test the model with a given input
  def predict(self, x_test):
    return self.model.predict(x_test)

# %%
from keras.layers.convolutional.separable_conv2d import SeparableConv2D
#LeNetCNN without Convolutional Layer
class LeNetCNN_v2:
  # constructor
  def __init__(self):
    self.model = None

  # Define structure of the CNN
  def build(self, input_dim):
    input = Input(shape = input_dim) # X dau vao cua minh
    S2 = MaxPooling2D(pool_size=(2, 2), padding="same")(input)
    S4 = MaxPooling2D(pool_size=(2, 2), padding="same")(S2)

    flat = Flatten()(S4)
    # These like ANN
    F5 = Dense(120, activation='relu', use_bias=True)(flat)
    F6 = Dense(84, activation='relu', use_bias=True)(F5)
    output = Dense(10, activation='softmax', use_bias=True)(F6) # y~ output
    self.model = Model(input, output)
  
  # Train the model
  def train(self, x_train, y_train, x_val, y_val): # x_train chinh la X, y_train chinh la ground-truth
    sgd = keras.optimizers.SGD(learning_rate=0.01)
    adam = keras.optimizers.Adam(learning_rate=0.01)
    self.model.compile(optimizer=sgd, loss = 'categorical_crossentropy', metrics=['accuracy'])
    self.model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = 50, batch_size = 128)
  
  # Load model from file
  def load(self, model_file):
    self.model = load_model(model_file)
  
  # save the trained model
  def save(self, model_file):
    self.model.save(model_file)
  
  # Show the architecture of the model
  def summary(self):
    self.model.summary()

  # Test the model with a given input
  def predict(self, x_test):
    return self.model.predict(x_test)

# %%
#LeNetCNN without Pooling Layer
class LeNetCNN_v3:
  # constructor
  def __init__(self):
    self.model = None

  # Define structure of the CNN
  def build(self, input_dim):
    input = Input(shape = input_dim) # X dau vao cua minh
    C1 = Conv2D(6, (3, 3), padding='same', activation='relu')(input)
    C3 = Conv2D(16, (3, 3), padding='same', activation='relu')(C1)

    flat = Flatten()(C3)
    # These like ANN
    F5 = Dense(120, activation='relu', use_bias=True)(flat)
    F6 = Dense(84, activation='relu', use_bias=True)(F5)
    output = Dense(10, activation='softmax', use_bias=True)(F6) # y~ output
    self.model = Model(input, output)
  
  # Train the model
  def train(self, x_train, y_train, x_val, y_val): # x_train chinh la X, y_train chinh la ground-truth
    sgd = keras.optimizers.SGD(learning_rate=0.01)
    adam = keras.optimizers.Adam(learning_rate=0.01)
    self.model.compile(optimizer=sgd, loss = 'categorical_crossentropy', metrics=['accuracy'])
    self.model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = 50, batch_size = 128)
  
  # Load model from file
  def load(self, model_file):
    self.model = load_model(model_file)
  
  # save the trained model
  def save(self, model_file):
    self.model.save(model_file)
  
  # Show the architecture of the model
  def summary(self):
    self.model.summary()

  # Test the model with a given input
  def predict(self, x_test):
    return self.model.predict(x_test)

# %% [markdown]
# #Base LeNetCNN

# %%
lenet = LeNetCNN()
lenet.build((28,28,1))
lenet.summary()
lenet.train(x_train_norm, y_train_oh, x_test_norm, y_test_oh)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 6)         60
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 6)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 16)        880
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 16)         0
#  2D)
#
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 120)               94200
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dense_2 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 106,154
# Trainable params: 106,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 26s 53ms/step - loss: 1.3669 - accuracy: 0.5787 - val_loss: 0.4240 - val_accuracy: 0.8747
# Epoch 2/50
# 469/469 [==============================] - 26s 55ms/step - loss: 0.3264 - accuracy: 0.8997 - val_loss: 0.2378 - val_accuracy: 0.9278
# Epoch 3/50
# 469/469 [==============================] - 29s 63ms/step - loss: 0.2271 - accuracy: 0.9294 - val_loss: 0.2062 - val_accuracy: 0.9347
# Epoch 4/50
# 469/469 [==============================] - 25s 53ms/step - loss: 0.1804 - accuracy: 0.9443 - val_loss: 0.1671 - val_accuracy: 0.9480
# Epoch 5/50
# 469/469 [==============================] - 30s 65ms/step - loss: 0.1509 - accuracy: 0.9538 - val_loss: 0.1552 - val_accuracy: 0.9515
# Epoch 6/50
# 469/469 [==============================] - 32s 67ms/step - loss: 0.1327 - accuracy: 0.9592 - val_loss: 0.1351 - val_accuracy: 0.9575
# Epoch 7/50
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1175 - accuracy: 0.9633 - val_loss: 0.1070 - val_accuracy: 0.9668
# Epoch 8/50
# 469/469 [==============================] - 30s 65ms/step - loss: 0.1057 - accuracy: 0.9673 - val_loss: 0.1131 - val_accuracy: 0.9644
# Epoch 9/50
# 469/469 [==============================] - 34s 72ms/step - loss: 0.0985 - accuracy: 0.9699 - val_loss: 0.1136 - val_accuracy: 0.9618
# Epoch 10/50
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0911 - accuracy: 0.9722 - val_loss: 0.0825 - val_accuracy: 0.9729
# Epoch 11/50
# 469/469 [==============================] - 25s 54ms/step - loss: 0.0866 - accuracy: 0.9734 - val_loss: 0.0880 - val_accuracy: 0.9714
# Epoch 12/50
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0807 - accuracy: 0.9756 - val_loss: 0.0753 - val_accuracy: 0.9746
# Epoch 13/50
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0762 - accuracy: 0.9765 - val_loss: 0.0764 - val_accuracy: 0.9750
# Epoch 14/50
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0730 - accuracy: 0.9773 - val_loss: 0.0684 - val_accuracy: 0.9775
# Epoch 15/50
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0695 - accuracy: 0.9787 - val_loss: 0.0691 - val_accuracy: 0.9771
# Epoch 16/50
# 469/469 [==============================] - 28s 59ms/step - loss: 0.0663 - accuracy: 0.9797 - val_loss: 0.0695 - val_accuracy: 0.9753
# Epoch 17/50
# 469/469 [==============================] - 26s 55ms/step - loss: 0.0636 - accuracy: 0.9801 - val_loss: 0.0648 - val_accuracy: 0.9776
# Epoch 18/50
# 469/469 [==============================] - 29s 61ms/step - loss: 0.0607 - accuracy: 0.9811 - val_loss: 0.0752 - val_accuracy: 0.9734
# Epoch 19/50
# 469/469 [==============================] - 31s 67ms/step - loss: 0.0587 - accuracy: 0.9817 - val_loss: 0.0665 - val_accuracy: 0.9779
# Epoch 20/50
# 469/469 [==============================] - 31s 65ms/step - loss: 0.0557 - accuracy: 0.9829 - val_loss: 0.0559 - val_accuracy: 0.9817
# Epoch 21/50
# 469/469 [==============================] - 32s 67ms/step - loss: 0.0539 - accuracy: 0.9831 - val_loss: 0.0700 - val_accuracy: 0.9763
# Epoch 22/50
# 469/469 [==============================] - 33s 71ms/step - loss: 0.0527 - accuracy: 0.9836 - val_loss: 0.0589 - val_accuracy: 0.9797
# Epoch 23/50
# 469/469 [==============================] - 28s 60ms/step - loss: 0.0509 - accuracy: 0.9841 - val_loss: 0.0555 - val_accuracy: 0.9814
# Epoch 24/50
# 469/469 [==============================] - 32s 69ms/step - loss: 0.0493 - accuracy: 0.9850 - val_loss: 0.0521 - val_accuracy: 0.9829
# Epoch 25/50
# 469/469 [==============================] - 34s 72ms/step - loss: 0.0476 - accuracy: 0.9854 - val_loss: 0.0543 - val_accuracy: 0.9815
# Epoch 26/50
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0457 - accuracy: 0.9854 - val_loss: 0.0533 - val_accuracy: 0.9819
# Epoch 27/50
# 469/469 [==============================] - 28s 60ms/step - loss: 0.0451 - accuracy: 0.9859 - val_loss: 0.0510 - val_accuracy: 0.9831
# Epoch 28/50
# 469/469 [==============================] - 27s 58ms/step - loss: 0.0432 - accuracy: 0.9865 - val_loss: 0.0504 - val_accuracy: 0.9837
# Epoch 29/50
# 469/469 [==============================] - 27s 57ms/step - loss: 0.0424 - accuracy: 0.9867 - val_loss: 0.0517 - val_accuracy: 0.9825
# Epoch 30/50
# 469/469 [==============================] - 27s 57ms/step - loss: 0.0417 - accuracy: 0.9866 - val_loss: 0.0493 - val_accuracy: 0.9836
# Epoch 31/50
# 469/469 [==============================] - 28s 59ms/step - loss: 0.0399 - accuracy: 0.9871 - val_loss: 0.0508 - val_accuracy: 0.9830
# Epoch 32/50
# 469/469 [==============================] - 27s 57ms/step - loss: 0.0387 - accuracy: 0.9875 - val_loss: 0.0492 - val_accuracy: 0.9834
# Epoch 33/50
# 469/469 [==============================] - 27s 57ms/step - loss: 0.0375 - accuracy: 0.9884 - val_loss: 0.0472 - val_accuracy: 0.9839
# Epoch 34/50
# 469/469 [==============================] - 27s 57ms/step - loss: 0.0369 - accuracy: 0.9881 - val_loss: 0.0498 - val_accuracy: 0.9834
# Epoch 35/50
# 469/469 [==============================] - 28s 59ms/step - loss: 0.0360 - accuracy: 0.9885 - val_loss: 0.0463 - val_accuracy: 0.9847
# Epoch 36/50
# 469/469 [==============================] - 27s 57ms/step - loss: 0.0355 - accuracy: 0.9886 - val_loss: 0.0461 - val_accuracy: 0.9844
# Epoch 37/50
# 469/469 [==============================] - 27s 57ms/step - loss: 0.0346 - accuracy: 0.9891 - val_loss: 0.0547 - val_accuracy: 0.9820
# Epoch 38/50
# 469/469 [==============================] - 28s 60ms/step - loss: 0.0331 - accuracy: 0.9896 - val_loss: 0.0498 - val_accuracy: 0.9828
# Epoch 39/50
# 469/469 [==============================] - 27s 58ms/step - loss: 0.0326 - accuracy: 0.9901 - val_loss: 0.0451 - val_accuracy: 0.9855
# Epoch 40/50
# 469/469 [==============================] - 27s 57ms/step - loss: 0.0313 - accuracy: 0.9900 - val_loss: 0.0454 - val_accuracy: 0.9850
# Epoch 41/50
# 469/469 [==============================] - 27s 58ms/step - loss: 0.0312 - accuracy: 0.9902 - val_loss: 0.0435 - val_accuracy: 0.9864
# Epoch 42/50
# 469/469 [==============================] - 28s 60ms/step - loss: 0.0295 - accuracy: 0.9911 - val_loss: 0.0435 - val_accuracy: 0.9864
# Epoch 43/50
# 469/469 [==============================] - 27s 58ms/step - loss: 0.0292 - accuracy: 0.9909 - val_loss: 0.0433 - val_accuracy: 0.9861
# Epoch 44/50
# 469/469 [==============================] - 27s 58ms/step - loss: 0.0287 - accuracy: 0.9908 - val_loss: 0.0444 - val_accuracy: 0.9845
# Epoch 45/50
# 469/469 [==============================] - 28s 60ms/step - loss: 0.0275 - accuracy: 0.9912 - val_loss: 0.0530 - val_accuracy: 0.9835
# Epoch 46/50
# 469/469 [==============================] - 27s 58ms/step - loss: 0.0272 - accuracy: 0.9914 - val_loss: 0.0529 - val_accuracy: 0.9812
# Epoch 47/50
# 469/469 [==============================] - 27s 58ms/step - loss: 0.0269 - accuracy: 0.9913 - val_loss: 0.0500 - val_accuracy: 0.9827
# Epoch 48/50
# 469/469 [==============================] - 27s 58ms/step - loss: 0.0257 - accuracy: 0.9919 - val_loss: 0.0494 - val_accuracy: 0.9830
# Epoch 49/50
# 469/469 [==============================] - 28s 60ms/step - loss: 0.0252 - accuracy: 0.9919 - val_loss: 0.0460 - val_accuracy: 0.9844
# Epoch 50/50
# 469/469 [==============================] - 27s 58ms/step - loss: 0.0245 - accuracy: 0.9923 - val_loss: 0.0490 - val_accuracy: 0.9829

# %% [markdown]
# Đánh giá độ chính xác: Mô hình LeNet sau khi train 50 epochs với dataset MNIST thì trả về được accuracy trên tập train cũng như test rất cao lên đến ~99% đối với tập train và ~98% đối với tập test. Điều này cho thấy mô hình dự đoán kết quả dựa trên dữ liệu MNIST là hiệu quả.

# %% [markdown]
# #LenetCNN without activate

# %%
lenet_v1 = LeNetCNN_v1()
lenet_v1.build((28,28,1))
lenet_v1.summary()
lenet_v1.train(x_train_norm, y_train_oh, x_test_norm, y_test_oh)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 6)         60
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 6)        0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 16)        880
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 16)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_3 (Dense)             (None, 120)               94200
#
#  dense_4 (Dense)             (None, 84)                10164
#
#  dense_5 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 106,154
# Trainable params: 106,154
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 26s 55ms/step - loss: 8.6925 - accuracy: 0.0985 - val_loss: 8.8682 - val_accuracy: 0.0958
# Epoch 2/50
# 469/469 [==============================] - 24s 52ms/step - loss: 9.0004 - accuracy: 0.0986 - val_loss: 8.9101 - val_accuracy: 0.0958
# Epoch 3/50
# 469/469 [==============================] - 26s 55ms/step - loss: 9.0643 - accuracy: 0.0986 - val_loss: 9.0552 - val_accuracy: 0.0958
# Epoch 4/50
# 469/469 [==============================] - 25s 53ms/step - loss: 9.1382 - accuracy: 0.0986 - val_loss: 8.9810 - val_accuracy: 0.0958
# Epoch 5/50
# 469/469 [==============================] - 25s 53ms/step - loss: 9.1403 - accuracy: 0.0986 - val_loss: 8.9891 - val_accuracy: 0.0958
# Epoch 6/50
# 469/469 [==============================] - 26s 56ms/step - loss: 9.1701 - accuracy: 0.0986 - val_loss: 9.0842 - val_accuracy: 0.0958
# Epoch 7/50
# 469/469 [==============================] - 25s 53ms/step - loss: 9.1881 - accuracy: 0.0986 - val_loss: 9.0261 - val_accuracy: 0.0958
# Epoch 8/50
# 469/469 [==============================] - 25s 54ms/step - loss: 9.1924 - accuracy: 0.0986 - val_loss: 9.1760 - val_accuracy: 0.0958
# Epoch 9/50
# 469/469 [==============================] - 25s 53ms/step - loss: 9.2354 - accuracy: 0.0986 - val_loss: 9.2099 - val_accuracy: 0.0958
# Epoch 10/50
# 469/469 [==============================] - 26s 56ms/step - loss: 9.3313 - accuracy: 0.0986 - val_loss: 9.2067 - val_accuracy: 0.0958
# Epoch 11/50
# 469/469 [==============================] - 25s 53ms/step - loss: 9.3592 - accuracy: 0.0986 - val_loss: 9.2824 - val_accuracy: 0.0958
# Epoch 12/50
# 469/469 [==============================] - 25s 53ms/step - loss: 9.3799 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 13/50
# 469/469 [==============================] - 27s 58ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 14/50
# 469/469 [==============================] - 26s 54ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 15/50
# 469/469 [==============================] - 26s 56ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 16/50
# 469/469 [==============================] - 27s 57ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 17/50
# 469/469 [==============================] - 27s 57ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 18/50
# 469/469 [==============================] - 26s 55ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 19/50
# 469/469 [==============================] - 26s 55ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 20/50
# 469/469 [==============================] - 27s 57ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 21/50
# 469/469 [==============================] - 26s 55ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 22/50
# 469/469 [==============================] - 26s 56ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 23/50
# 469/469 [==============================] - 25s 54ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 24/50
# 469/469 [==============================] - 27s 57ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 25/50
# 469/469 [==============================] - 26s 56ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 26/50
# 469/469 [==============================] - 26s 55ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 27/50
# 469/469 [==============================] - 27s 57ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 28/50
# 469/469 [==============================] - 26s 55ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 29/50
# 469/469 [==============================] - 27s 57ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 30/50
# 469/469 [==============================] - 26s 55ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 31/50
# 469/469 [==============================] - 26s 56ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 32/50
# 469/469 [==============================] - 28s 60ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 33/50
# 469/469 [==============================] - 26s 56ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 34/50
# 469/469 [==============================] - 26s 56ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 35/50
# 469/469 [==============================] - 27s 57ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 36/50
# 469/469 [==============================] - 26s 56ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 37/50
# 469/469 [==============================] - 26s 56ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 38/50
# 469/469 [==============================] - 26s 55ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 39/50
# 469/469 [==============================] - 28s 60ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 40/50
# 469/469 [==============================] - 28s 59ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 41/50
# 469/469 [==============================] - 27s 58ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 42/50
# 469/469 [==============================] - 29s 61ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 43/50
# 469/469 [==============================] - 27s 57ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 44/50
# 469/469 [==============================] - 27s 58ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 45/50
# 469/469 [==============================] - 28s 59ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 46/50
# 469/469 [==============================] - 28s 60ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 47/50
# 469/469 [==============================] - 27s 58ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 48/50
# 469/469 [==============================] - 27s 57ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 49/50
# 469/469 [==============================] - 28s 60ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958
# Epoch 50/50
# 469/469 [==============================] - 26s 56ms/step - loss: 9.3985 - accuracy: 0.0986 - val_loss: 9.3195 - val_accuracy: 0.0958

# %% [markdown]
# Đánh giá độ chính xác: Sau khi loại bỏ activation thì độ chính xác của model đã giảm đi rất nhiều khi train/test.

# %% [markdown]
# #LenetCNN without Conv Layer

# %%
lenet_v2 = LeNetCNN_v2()
lenet_v2.build((28,28,1))
lenet_v2.summary()
lenet_v2.train(x_train_norm, y_train_oh, x_test_norm, y_test_oh)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  max_pooling2d_4 (MaxPooling  (None, 14, 14, 1)        0
#  2D)
#
#  max_pooling2d_5 (MaxPooling  (None, 7, 7, 1)          0
#  2D)
#
#  flatten_2 (Flatten)         (None, 49)                0
#
#  dense_6 (Dense)             (None, 120)               6000
#
#  dense_7 (Dense)             (None, 84)                10164
#
#  dense_8 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 17,014
# Trainable params: 17,014
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 3s 6ms/step - loss: 1.9486 - accuracy: 0.4478 - val_loss: 1.5260 - val_accuracy: 0.6474
# Epoch 2/50
# 469/469 [==============================] - 5s 10ms/step - loss: 1.2093 - accuracy: 0.6880 - val_loss: 0.9649 - val_accuracy: 0.7345
# Epoch 3/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.8670 - accuracy: 0.7459 - val_loss: 0.7747 - val_accuracy: 0.7755
# Epoch 4/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.7369 - accuracy: 0.7760 - val_loss: 0.6856 - val_accuracy: 0.7918
# Epoch 5/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.6674 - accuracy: 0.7935 - val_loss: 0.6324 - val_accuracy: 0.8056
# Epoch 6/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.6232 - accuracy: 0.8046 - val_loss: 0.5975 - val_accuracy: 0.8159
# Epoch 7/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.5924 - accuracy: 0.8130 - val_loss: 0.5744 - val_accuracy: 0.8206
# Epoch 8/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.5701 - accuracy: 0.8185 - val_loss: 0.5554 - val_accuracy: 0.8248
# Epoch 9/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.5528 - accuracy: 0.8238 - val_loss: 0.5410 - val_accuracy: 0.8272
# Epoch 10/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.5392 - accuracy: 0.8260 - val_loss: 0.5276 - val_accuracy: 0.8325
# Epoch 11/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.5276 - accuracy: 0.8308 - val_loss: 0.5200 - val_accuracy: 0.8333
# Epoch 12/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.5178 - accuracy: 0.8335 - val_loss: 0.5102 - val_accuracy: 0.8370
# Epoch 13/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.5087 - accuracy: 0.8362 - val_loss: 0.5029 - val_accuracy: 0.8389
# Epoch 14/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.5008 - accuracy: 0.8382 - val_loss: 0.4947 - val_accuracy: 0.8417
# Epoch 15/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4937 - accuracy: 0.8398 - val_loss: 0.4872 - val_accuracy: 0.8442
# Epoch 16/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.4864 - accuracy: 0.8424 - val_loss: 0.4802 - val_accuracy: 0.8449
# Epoch 17/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.4794 - accuracy: 0.8445 - val_loss: 0.4762 - val_accuracy: 0.8460
# Epoch 18/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4735 - accuracy: 0.8456 - val_loss: 0.4695 - val_accuracy: 0.8487
# Epoch 19/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4672 - accuracy: 0.8477 - val_loss: 0.4651 - val_accuracy: 0.8496
# Epoch 20/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.4613 - accuracy: 0.8497 - val_loss: 0.4604 - val_accuracy: 0.8509
# Epoch 21/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4557 - accuracy: 0.8517 - val_loss: 0.4570 - val_accuracy: 0.8529
# Epoch 22/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4502 - accuracy: 0.8525 - val_loss: 0.4465 - val_accuracy: 0.8549
# Epoch 23/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4452 - accuracy: 0.8545 - val_loss: 0.4470 - val_accuracy: 0.8564
# Epoch 24/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4400 - accuracy: 0.8552 - val_loss: 0.4400 - val_accuracy: 0.8565
# Epoch 25/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4354 - accuracy: 0.8569 - val_loss: 0.4362 - val_accuracy: 0.8595
# Epoch 26/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4308 - accuracy: 0.8589 - val_loss: 0.4309 - val_accuracy: 0.8618
# Epoch 27/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4263 - accuracy: 0.8605 - val_loss: 0.4257 - val_accuracy: 0.8626
# Epoch 28/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4223 - accuracy: 0.8611 - val_loss: 0.4236 - val_accuracy: 0.8639
# Epoch 29/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.4182 - accuracy: 0.8628 - val_loss: 0.4184 - val_accuracy: 0.8652
# Epoch 30/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4142 - accuracy: 0.8642 - val_loss: 0.4166 - val_accuracy: 0.8642
# Epoch 31/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4107 - accuracy: 0.8658 - val_loss: 0.4138 - val_accuracy: 0.8679
# Epoch 32/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4070 - accuracy: 0.8659 - val_loss: 0.4081 - val_accuracy: 0.8687
# Epoch 33/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4036 - accuracy: 0.8671 - val_loss: 0.4069 - val_accuracy: 0.8717
# Epoch 34/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3999 - accuracy: 0.8683 - val_loss: 0.4060 - val_accuracy: 0.8726
# Epoch 35/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3964 - accuracy: 0.8702 - val_loss: 0.4030 - val_accuracy: 0.8731
# Epoch 36/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3937 - accuracy: 0.8711 - val_loss: 0.3967 - val_accuracy: 0.8738
# Epoch 37/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.3905 - accuracy: 0.8714 - val_loss: 0.3967 - val_accuracy: 0.8725
# Epoch 38/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3875 - accuracy: 0.8732 - val_loss: 0.3929 - val_accuracy: 0.8752
# Epoch 39/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3849 - accuracy: 0.8750 - val_loss: 0.3895 - val_accuracy: 0.8751
# Epoch 40/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3822 - accuracy: 0.8751 - val_loss: 0.3867 - val_accuracy: 0.8758
# Epoch 41/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3794 - accuracy: 0.8763 - val_loss: 0.3861 - val_accuracy: 0.8760
# Epoch 42/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3768 - accuracy: 0.8764 - val_loss: 0.3851 - val_accuracy: 0.8765
# Epoch 43/50
# 469/469 [==============================] - 4s 7ms/step - loss: 0.3741 - accuracy: 0.8770 - val_loss: 0.3816 - val_accuracy: 0.8789
# Epoch 44/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3719 - accuracy: 0.8781 - val_loss: 0.3786 - val_accuracy: 0.8790
# Epoch 45/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3694 - accuracy: 0.8791 - val_loss: 0.3771 - val_accuracy: 0.8781
# Epoch 46/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3674 - accuracy: 0.8802 - val_loss: 0.3742 - val_accuracy: 0.8809
# Epoch 47/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3652 - accuracy: 0.8807 - val_loss: 0.3729 - val_accuracy: 0.8796
# Epoch 48/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3629 - accuracy: 0.8813 - val_loss: 0.3717 - val_accuracy: 0.8808
# Epoch 49/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.3607 - accuracy: 0.8820 - val_loss: 0.3685 - val_accuracy: 0.8821
# Epoch 50/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.3586 - accuracy: 0.8825 - val_loss: 0.3679 - val_accuracy: 0.8811

# %% [markdown]
# Đánh giá độ chính xác: Việc loại bỏ Convolutional Layer có vẻ như một phần ảnh hưởng tới độ chính xác của model khi nó giảm khoảng 10% độ chính xác kể cả trên tập train và tập test.

# %% [markdown]
# #LeNetCNN without Pooling

# %%
lenet_v3 = LeNetCNN_v3()
lenet_v3.build((28,28,1))
lenet_v3.summary()
lenet_v3.train(x_train_norm, y_train_oh, x_test_norm, y_test_oh)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 6)         60
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 16)        880
#
#  flatten_3 (Flatten)         (None, 12544)             0
#
#  dense_9 (Dense)             (None, 120)               1505400
#
#  dense_10 (Dense)            (None, 84)                10164
#
#  dense_11 (Dense)            (None, 10)                850
#
# =================================================================
# Total params: 1,517,354
# Trainable params: 1,517,354
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 52s 109ms/step - loss: 0.9472 - accuracy: 0.7213 - val_loss: 0.2826 - val_accuracy: 0.9174
# Epoch 2/50
# 469/469 [==============================] - 52s 110ms/step - loss: 0.2365 - accuracy: 0.9304 - val_loss: 0.2201 - val_accuracy: 0.9349
# Epoch 3/50
# 469/469 [==============================] - 51s 108ms/step - loss: 0.1732 - accuracy: 0.9485 - val_loss: 0.1553 - val_accuracy: 0.9511
# Epoch 4/50
# 469/469 [==============================] - 52s 110ms/step - loss: 0.1392 - accuracy: 0.9586 - val_loss: 0.1181 - val_accuracy: 0.9633
# Epoch 5/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.1178 - accuracy: 0.9650 - val_loss: 0.1077 - val_accuracy: 0.9662
# Epoch 6/50
# 469/469 [==============================] - 53s 112ms/step - loss: 0.1020 - accuracy: 0.9696 - val_loss: 0.1204 - val_accuracy: 0.9619
# Epoch 7/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.0916 - accuracy: 0.9722 - val_loss: 0.1009 - val_accuracy: 0.9684
# Epoch 8/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0811 - accuracy: 0.9754 - val_loss: 0.0824 - val_accuracy: 0.9745
# Epoch 9/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.0735 - accuracy: 0.9776 - val_loss: 0.0916 - val_accuracy: 0.9714
# Epoch 10/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0688 - accuracy: 0.9788 - val_loss: 0.0933 - val_accuracy: 0.9695
# Epoch 11/50
# 469/469 [==============================] - 51s 108ms/step - loss: 0.0642 - accuracy: 0.9800 - val_loss: 0.0723 - val_accuracy: 0.9772
# Epoch 12/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0577 - accuracy: 0.9816 - val_loss: 0.0754 - val_accuracy: 0.9758
# Epoch 13/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.0547 - accuracy: 0.9831 - val_loss: 0.0813 - val_accuracy: 0.9748
# Epoch 14/50
# 469/469 [==============================] - 52s 110ms/step - loss: 0.0502 - accuracy: 0.9850 - val_loss: 0.0853 - val_accuracy: 0.9730
# Epoch 15/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0470 - accuracy: 0.9858 - val_loss: 0.0760 - val_accuracy: 0.9770
# Epoch 16/50
# 469/469 [==============================] - 51s 108ms/step - loss: 0.0444 - accuracy: 0.9863 - val_loss: 0.0695 - val_accuracy: 0.9782
# Epoch 17/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.0430 - accuracy: 0.9867 - val_loss: 0.0777 - val_accuracy: 0.9740
# Epoch 18/50
# 469/469 [==============================] - 54s 115ms/step - loss: 0.0389 - accuracy: 0.9880 - val_loss: 0.0722 - val_accuracy: 0.9762
# Epoch 19/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0364 - accuracy: 0.9888 - val_loss: 0.0759 - val_accuracy: 0.9761
# Epoch 20/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.0349 - accuracy: 0.9892 - val_loss: 0.0692 - val_accuracy: 0.9784
# Epoch 21/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.0320 - accuracy: 0.9901 - val_loss: 0.0697 - val_accuracy: 0.9780
# Epoch 22/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0303 - accuracy: 0.9909 - val_loss: 0.0649 - val_accuracy: 0.9811
# Epoch 23/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0288 - accuracy: 0.9915 - val_loss: 0.0681 - val_accuracy: 0.9789
# Epoch 24/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.0268 - accuracy: 0.9916 - val_loss: 0.0668 - val_accuracy: 0.9795
# Epoch 25/50
# 469/469 [==============================] - 54s 115ms/step - loss: 0.0244 - accuracy: 0.9927 - val_loss: 0.0636 - val_accuracy: 0.9810
# Epoch 26/50
# 469/469 [==============================] - 52s 110ms/step - loss: 0.0238 - accuracy: 0.9929 - val_loss: 0.0667 - val_accuracy: 0.9795
# Epoch 27/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0228 - accuracy: 0.9930 - val_loss: 0.0739 - val_accuracy: 0.9775
# Epoch 28/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.0206 - accuracy: 0.9938 - val_loss: 0.0619 - val_accuracy: 0.9812
# Epoch 29/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0197 - accuracy: 0.9942 - val_loss: 0.0653 - val_accuracy: 0.9809
# Epoch 30/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.0197 - accuracy: 0.9940 - val_loss: 0.0800 - val_accuracy: 0.9754
# Epoch 31/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0176 - accuracy: 0.9950 - val_loss: 0.0603 - val_accuracy: 0.9818
# Epoch 32/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.0160 - accuracy: 0.9955 - val_loss: 0.0649 - val_accuracy: 0.9811
# Epoch 33/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0161 - accuracy: 0.9953 - val_loss: 0.0649 - val_accuracy: 0.9800
# Epoch 34/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.0152 - accuracy: 0.9958 - val_loss: 0.0922 - val_accuracy: 0.9738
# Epoch 35/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0155 - accuracy: 0.9956 - val_loss: 0.0752 - val_accuracy: 0.9779
# Epoch 36/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.0130 - accuracy: 0.9964 - val_loss: 0.0681 - val_accuracy: 0.9803
# Epoch 37/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0119 - accuracy: 0.9971 - val_loss: 0.0664 - val_accuracy: 0.9810
# Epoch 38/50
# 469/469 [==============================] - 53s 112ms/step - loss: 0.0113 - accuracy: 0.9967 - val_loss: 0.0655 - val_accuracy: 0.9813
# Epoch 39/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.0099 - accuracy: 0.9975 - val_loss: 0.0659 - val_accuracy: 0.9819
# Epoch 40/50
# 469/469 [==============================] - 51s 110ms/step - loss: 0.0099 - accuracy: 0.9974 - val_loss: 0.0642 - val_accuracy: 0.9820
# Epoch 41/50
# 469/469 [==============================] - 52s 112ms/step - loss: 0.0093 - accuracy: 0.9977 - val_loss: 0.0676 - val_accuracy: 0.9823
# Epoch 42/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0094 - accuracy: 0.9972 - val_loss: 0.0639 - val_accuracy: 0.9811
# Epoch 43/50
# 469/469 [==============================] - 51s 109ms/step - loss: 0.0084 - accuracy: 0.9979 - val_loss: 0.0711 - val_accuracy: 0.9808
# Epoch 44/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0076 - accuracy: 0.9980 - val_loss: 0.0636 - val_accuracy: 0.9822
# Epoch 45/50
# 469/469 [==============================] - 53s 112ms/step - loss: 0.0074 - accuracy: 0.9981 - val_loss: 0.0718 - val_accuracy: 0.9814
# Epoch 46/50
# 469/469 [==============================] - 53s 112ms/step - loss: 0.0066 - accuracy: 0.9984 - val_loss: 0.0645 - val_accuracy: 0.9830
# Epoch 47/50
# 469/469 [==============================] - 51s 110ms/step - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.0679 - val_accuracy: 0.9812
# Epoch 48/50
# 469/469 [==============================] - 52s 112ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.0706 - val_accuracy: 0.9822
# Epoch 49/50
# 469/469 [==============================] - 52s 110ms/step - loss: 0.0046 - accuracy: 0.9991 - val_loss: 0.0700 - val_accuracy: 0.9811
# Epoch 50/50
# 469/469 [==============================] - 52s 111ms/step - loss: 0.0042 - accuracy: 0.9992 - val_loss: 0.0790 - val_accuracy: 0.9803

# %% [markdown]
# Nhận xét độ chính xác: Độ chính xác trên tập train gần như tuyệt đối nhưng trên tập test thì không thay đổi so với kiến trúc mạng gốc.
